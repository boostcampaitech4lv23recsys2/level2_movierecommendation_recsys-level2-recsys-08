# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

import os
import json
import argparse
import pandas as pd
import numpy as np
import time, datetime
from tqdm import tqdm
from logging import getLogger
import torch

from recbole.quick_start import run_recbole
import wandb

# %%
# train load
train = pd.read_csv("/opt/ml/input/data/train/train_ratings.csv")

# indexing save
user2idx = {v:k for k,v in enumerate(sorted(set(train.user)))}
item2idx = {v:k for k,v in enumerate(sorted(set(train.item)))}
uidx2user = {k:v for k,v in enumerate(sorted(set(train.user)))}
iidx2item = {k:v for k,v in enumerate(sorted(set(train.item)))}

# %%
train.user = train.user.map(user2idx)
train.item = train.item.map(item2idx)

train.columns=['user_id:token','item_id:token','timestamp:float']

outpath = f"dataset/train_data"
os.makedirs(outpath, exist_ok=True)
# sub_train=train.groupby("user").sample(n=10, random_state=SEED)
# sub_train.shape
train.to_csv(os.path.join(outpath,"train_data.inter"),sep='\t',index=False)

# %%
yamldata="""
USER_ID_FIELD: user_id
ITEM_ID_FIELD: item_id
TIME_FIELD: timestamp

load_col:
    inter: [user_id, item_id, timestamp]

show_progress : False
epochs : 30
device : torch.device("cuda" if torch.cuda.is_available() else "cpu")
eval_args:
    split: {'RS': [8, 1, 1]}
    group_by: user
    order: RO
    mode: full
metrics: ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
topk: 10
valid_metric: Recall@10

log_wandb : True
wandb_project : Recbole

mlp_hidden_size : [600,400,200]
"""
with open("general.yaml", "w") as f:
    f.write(yamldata)
# Out:
# 484

# %%
def run(model_name):
    if model_name in [
        "MultiVAE",
        "MultiDAE",
        "MacridVAE",
        "RecVAE",
        "GRU4Rec",
        "NARM",
        "STAMP",
        "NextItNet",
        "TransRec",
        "SASRec",
        "BERT4Rec",
        "SRGNN",
        "GCSAN",
        "GRU4RecF",
        "FOSSIL",
        "SHAN",
        "RepeatNet",
        "HRM",
        "NPE",
    ]:
        parameter_dict = {
            "neg_sampling": None,
        }
        return run_recbole(
            model=model_name,
            dataset='train_data',
            config_file_list=['general.yaml'],
            config_dict=parameter_dict,
        )
    else:
        return run_recbole(
            model=model_name,
            dataset='train_data',
            config_file_list=['general.yaml'],
        )

# %%
model_list = ['MultiVAE','NeuMF','MultiDAE','CDAE','RecVAE','EASE','SLIMElastic','ADMMSLIM']
for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run(model_name)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
# Out:
# running MultiVAE...
# 26 Dec 15:50    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 15:50    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600, 400, 200]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 15:50    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 15:51    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 15:51    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 15:51    WARNING  Max value of user's history interaction records has reached 34.22444183313749% of the total.
# 26 Dec 15:51    INFO  MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=6808, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=200, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=200, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=200, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=200, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=600, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=600, out_features=6808, bias=True)
#   )
# )
# Trainable parameters: 8857336
# 26 Dec 15:51    INFO  FLOPs: 8848000.0
# 26 Dec 15:51    ERROR  Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ujoon (recsys8). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/opt/ml/input/MR/Recbole/general/wandb/run-20221226_155123-2ut4hd74</code>
# Syncing run <strong><a href="https://wandb.ai/recsys8/Recbole/runs/2ut4hd74" target="_blank">firm-dew-2</a></strong> to <a href="https://wandb.ai/recsys8/Recbole" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 26 Dec 15:51    INFO  epoch 0 training [time: 0.21s, train loss: 17059.0038]
# 26 Dec 15:52    INFO  epoch 0 evaluating [time: 47.75s, valid_score: 0.077600]
# 26 Dec 15:52    INFO  valid result:
# recall@10 : 0.0776    mrr@10 : 0.2652    ndcg@10 : 0.1186    hit@10 : 0.5677    precision@10 : 0.0993    map@10 : 0.0525
# 26 Dec 15:52    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:52    INFO  epoch 1 training [time: 0.21s, train loss: 16411.2237]
# 26 Dec 15:53    INFO  epoch 1 evaluating [time: 48.52s, valid_score: 0.077500]
# 26 Dec 15:53    INFO  valid result:
# recall@10 : 0.0775    mrr@10 : 0.2671    ndcg@10 : 0.1193    hit@10 : 0.5676    precision@10 : 0.0998    map@10 : 0.053
# 26 Dec 15:53    INFO  epoch 2 training [time: 0.20s, train loss: 16398.4192]
# 26 Dec 15:53    INFO  epoch 2 evaluating [time: 48.10s, valid_score: 0.080500]
# 26 Dec 15:53    INFO  valid result:
# recall@10 : 0.0805    mrr@10 : 0.2739    ndcg@10 : 0.1239    hit@10 : 0.5743    precision@10 : 0.1034    map@10 : 0.056
# 26 Dec 15:53    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:53    INFO  epoch 3 training [time: 0.21s, train loss: 16399.5583]
# 26 Dec 15:54    INFO  epoch 3 evaluating [time: 48.64s, valid_score: 0.080500]
# 26 Dec 15:54    INFO  valid result:
# recall@10 : 0.0805    mrr@10 : 0.277    ndcg@10 : 0.1248    hit@10 : 0.5729    precision@10 : 0.1037    map@10 : 0.0567
# 26 Dec 15:54    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:54    INFO  epoch 4 training [time: 0.20s, train loss: 16394.8901]
# 26 Dec 15:55    INFO  epoch 4 evaluating [time: 48.89s, valid_score: 0.080500]
# 26 Dec 15:55    INFO  valid result:
# recall@10 : 0.0805    mrr@10 : 0.2772    ndcg@10 : 0.1249    hit@10 : 0.5745    precision@10 : 0.1038    map@10 : 0.0567
# 26 Dec 15:55    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:55    INFO  epoch 5 training [time: 0.21s, train loss: 16308.4203]
# 26 Dec 15:56    INFO  epoch 5 evaluating [time: 48.45s, valid_score: 0.079700]
# 26 Dec 15:56    INFO  valid result:
# recall@10 : 0.0797    mrr@10 : 0.2748    ndcg@10 : 0.1234    hit@10 : 0.5745    precision@10 : 0.1027    map@10 : 0.0556
# 26 Dec 15:56    INFO  epoch 6 training [time: 0.20s, train loss: 16247.5200]
# 26 Dec 15:57    INFO  epoch 6 evaluating [time: 48.12s, valid_score: 0.082800]
# 26 Dec 15:57    INFO  valid result:
# recall@10 : 0.0828    mrr@10 : 0.2789    ndcg@10 : 0.1267    hit@10 : 0.5861    precision@10 : 0.106    map@10 : 0.0574
# 26 Dec 15:57    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:57    INFO  epoch 7 training [time: 0.20s, train loss: 16147.3154]
# 26 Dec 15:57    INFO  epoch 7 evaluating [time: 48.00s, valid_score: 0.084500]
# 26 Dec 15:57    INFO  valid result:
# recall@10 : 0.0845    mrr@10 : 0.2829    ndcg@10 : 0.1292    hit@10 : 0.5922    precision@10 : 0.1084    map@10 : 0.0586
# 26 Dec 15:57    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:57    INFO  epoch 8 training [time: 0.21s, train loss: 16123.5688]
# 26 Dec 15:58    INFO  epoch 8 evaluating [time: 48.23s, valid_score: 0.086600]
# 26 Dec 15:58    INFO  valid result:
# recall@10 : 0.0866    mrr@10 : 0.2886    ndcg@10 : 0.1319    hit@10 : 0.602    precision@10 : 0.1104    map@10 : 0.06
# 26 Dec 15:58    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:58    INFO  epoch 9 training [time: 0.20s, train loss: 16076.8230]
# 26 Dec 15:59    INFO  epoch 9 evaluating [time: 48.33s, valid_score: 0.088000]
# 26 Dec 15:59    INFO  valid result:
# recall@10 : 0.088    mrr@10 : 0.2919    ndcg@10 : 0.1343    hit@10 : 0.6074    precision@10 : 0.1129    map@10 : 0.0613
# 26 Dec 15:59    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 15:59    INFO  epoch 10 training [time: 0.20s, train loss: 16061.8522]
# 26 Dec 16:00    INFO  epoch 10 evaluating [time: 48.64s, valid_score: 0.089400]
# 26 Dec 16:00    INFO  valid result:
# recall@10 : 0.0894    mrr@10 : 0.2996    ndcg@10 : 0.1376    hit@10 : 0.6152    precision@10 : 0.1155    map@10 : 0.0631
# 26 Dec 16:00    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:00    INFO  epoch 11 training [time: 0.21s, train loss: 15923.3813]
# 26 Dec 16:01    INFO  epoch 11 evaluating [time: 48.58s, valid_score: 0.094600]
# 26 Dec 16:01    INFO  valid result:
# recall@10 : 0.0946    mrr@10 : 0.3076    ndcg@10 : 0.144    hit@10 : 0.6387    precision@10 : 0.1219    map@10 : 0.0661
# 26 Dec 16:01    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:01    INFO  epoch 12 training [time: 0.21s, train loss: 15796.0760]
# 26 Dec 16:02    INFO  epoch 12 evaluating [time: 48.48s, valid_score: 0.096900]
# 26 Dec 16:02    INFO  valid result:
# recall@10 : 0.0969    mrr@10 : 0.3154    ndcg@10 : 0.1478    hit@10 : 0.6482    precision@10 : 0.1247    map@10 : 0.0683
# 26 Dec 16:02    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:02    INFO  epoch 13 training [time: 0.21s, train loss: 15813.3998]
# 26 Dec 16:02    INFO  epoch 13 evaluating [time: 48.10s, valid_score: 0.097200]
# 26 Dec 16:02    INFO  valid result:
# recall@10 : 0.0972    mrr@10 : 0.3197    ndcg@10 : 0.1496    hit@10 : 0.6496    precision@10 : 0.126    map@10 : 0.0695
# 26 Dec 16:02    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:02    INFO  epoch 14 training [time: 0.20s, train loss: 15778.3900]
# 26 Dec 16:03    INFO  epoch 14 evaluating [time: 48.28s, valid_score: 0.098200]
# 26 Dec 16:03    INFO  valid result:
# recall@10 : 0.0982    mrr@10 : 0.3218    ndcg@10 : 0.1508    hit@10 : 0.6548    precision@10 : 0.1269    map@10 : 0.0701
# 26 Dec 16:03    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:03    INFO  epoch 15 training [time: 0.20s, train loss: 15742.3859]
# 26 Dec 16:04    INFO  epoch 15 evaluating [time: 48.35s, valid_score: 0.097700]
# 26 Dec 16:04    INFO  valid result:
# recall@10 : 0.0977    mrr@10 : 0.3236    ndcg@10 : 0.1508    hit@10 : 0.6556    precision@10 : 0.1269    map@10 : 0.0699
# 26 Dec 16:04    INFO  epoch 16 training [time: 0.21s, train loss: 15642.4792]
# 26 Dec 16:05    INFO  epoch 16 evaluating [time: 48.21s, valid_score: 0.100400]
# 26 Dec 16:05    INFO  valid result:
# recall@10 : 0.1004    mrr@10 : 0.323    ndcg@10 : 0.1522    hit@10 : 0.6627    precision@10 : 0.1286    map@10 : 0.0705
# 26 Dec 16:05    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:05    INFO  epoch 17 training [time: 0.20s, train loss: 15569.8079]
# 26 Dec 16:06    INFO  epoch 17 evaluating [time: 48.69s, valid_score: 0.101800]
# 26 Dec 16:06    INFO  valid result:
# recall@10 : 0.1018    mrr@10 : 0.3303    ndcg@10 : 0.1556    hit@10 : 0.6682    precision@10 : 0.1309    map@10 : 0.0726
# 26 Dec 16:06    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:06    INFO  epoch 18 training [time: 0.21s, train loss: 15577.2041]
# 26 Dec 16:06    INFO  epoch 18 evaluating [time: 48.22s, valid_score: 0.103100]
# 26 Dec 16:06    INFO  valid result:
# recall@10 : 0.1031    mrr@10 : 0.3357    ndcg@10 : 0.1577    hit@10 : 0.6738    precision@10 : 0.1321    map@10 : 0.0738
# 26 Dec 16:06    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:06    INFO  epoch 19 training [time: 0.21s, train loss: 15519.3611]
# 26 Dec 16:07    INFO  epoch 19 evaluating [time: 48.63s, valid_score: 0.104300]
# 26 Dec 16:07    INFO  valid result:
# recall@10 : 0.1043    mrr@10 : 0.3387    ndcg@10 : 0.1597    hit@10 : 0.6779    precision@10 : 0.1342    map@10 : 0.0749
# 26 Dec 16:07    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:07    INFO  epoch 20 training [time: 0.21s, train loss: 15488.4503]
# 26 Dec 16:08    INFO  epoch 20 evaluating [time: 48.16s, valid_score: 0.107100]
# 26 Dec 16:08    INFO  valid result:
# recall@10 : 0.1071    mrr@10 : 0.3398    ndcg@10 : 0.1627    hit@10 : 0.6871    precision@10 : 0.1376    map@10 : 0.0765
# 26 Dec 16:08    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:08    INFO  epoch 21 training [time: 0.21s, train loss: 15415.2392]
# 26 Dec 16:09    INFO  epoch 21 evaluating [time: 48.39s, valid_score: 0.108000]
# 26 Dec 16:09    INFO  valid result:
# recall@10 : 0.108    mrr@10 : 0.341    ndcg@10 : 0.1627    hit@10 : 0.6907    precision@10 : 0.1373    map@10 : 0.0761
# 26 Dec 16:09    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:09    INFO  epoch 22 training [time: 0.21s, train loss: 15358.5353]
# 26 Dec 16:10    INFO  epoch 22 evaluating [time: 48.30s, valid_score: 0.109100]
# 26 Dec 16:10    INFO  valid result:
# recall@10 : 0.1091    mrr@10 : 0.3454    ndcg@10 : 0.165    hit@10 : 0.6948    precision@10 : 0.1391    map@10 : 0.0775
# 26 Dec 16:10    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:10    INFO  epoch 23 training [time: 0.20s, train loss: 15395.5486]
# 26 Dec 16:11    INFO  epoch 23 evaluating [time: 48.38s, valid_score: 0.111600]
# 26 Dec 16:11    INFO  valid result:
# recall@10 : 0.1116    mrr@10 : 0.3518    ndcg@10 : 0.1685    hit@10 : 0.7014    precision@10 : 0.1419    map@10 : 0.0794
# 26 Dec 16:11    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:11    INFO  epoch 24 training [time: 0.21s, train loss: 15348.0225]
# 26 Dec 16:11    INFO  epoch 24 evaluating [time: 48.33s, valid_score: 0.114000]
# 26 Dec 16:11    INFO  valid result:
# recall@10 : 0.114    mrr@10 : 0.3557    ndcg@10 : 0.1718    hit@10 : 0.7091    precision@10 : 0.1449    map@10 : 0.0814
# 26 Dec 16:11    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:11    INFO  epoch 25 training [time: 0.20s, train loss: 15230.8584]
# 26 Dec 16:12    INFO  epoch 25 evaluating [time: 48.37s, valid_score: 0.116100]
# 26 Dec 16:12    INFO  valid result:
# recall@10 : 0.1161    mrr@10 : 0.3613    ndcg@10 : 0.175    hit@10 : 0.7152    precision@10 : 0.1473    map@10 : 0.0833
# 26 Dec 16:12    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:12    INFO  epoch 26 training [time: 0.21s, train loss: 15253.1192]
# 26 Dec 16:13    INFO  epoch 26 evaluating [time: 48.10s, valid_score: 0.117500]
# 26 Dec 16:13    INFO  valid result:
# recall@10 : 0.1175    mrr@10 : 0.3641    ndcg@10 : 0.1769    hit@10 : 0.7206    precision@10 : 0.1491    map@10 : 0.0843
# 26 Dec 16:13    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:13    INFO  epoch 27 training [time: 0.21s, train loss: 15210.6933]
# 26 Dec 16:14    INFO  epoch 27 evaluating [time: 47.88s, valid_score: 0.119300]
# 26 Dec 16:14    INFO  valid result:
# recall@10 : 0.1193    mrr@10 : 0.3621    ndcg@10 : 0.1778    hit@10 : 0.726    precision@10 : 0.1508    map@10 : 0.0846
# 26 Dec 16:14    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:14    INFO  epoch 28 training [time: 0.21s, train loss: 15191.6709]
# 26 Dec 16:15    INFO  epoch 28 evaluating [time: 48.54s, valid_score: 0.120800]
# 26 Dec 16:15    INFO  valid result:
# recall@10 : 0.1208    mrr@10 : 0.3693    ndcg@10 : 0.1808    hit@10 : 0.7317    precision@10 : 0.1529    map@10 : 0.0863
# 26 Dec 16:15    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:15    INFO  epoch 29 training [time: 0.20s, train loss: 15151.7910]
# 26 Dec 16:15    INFO  epoch 29 evaluating [time: 48.09s, valid_score: 0.122300]
# 26 Dec 16:15    INFO  valid result:
# recall@10 : 0.1223    mrr@10 : 0.3717    ndcg@10 : 0.1819    hit@10 : 0.7391    precision@10 : 0.1537    map@10 : 0.0866
# 26 Dec 16:15    INFO  Saving current: saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:15    INFO  Loading model structure and parameters from saved/MultiVAE-Dec-26-2022_15-51-27.pth
# 26 Dec 16:16    INFO  best valid : OrderedDict([('recall@10', 0.1223), ('mrr@10', 0.3717), ('ndcg@10', 0.1819), ('hit@10', 0.7391), ('precision@10', 0.1537), ('map@10', 0.0866)])
# 26 Dec 16:16    INFO  test result: OrderedDict([('recall@10', 0.1365), ('mrr@10', 0.4322), ('ndcg@10', 0.2182), ('hit@10', 0.7603), ('precision@10', 0.1806), ('map@10', 0.1145)])
# It took 26.35 mins
# {'best_valid_score': 0.1223, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1223), ('mrr@10', 0.3717), ('ndcg@10', 0.1819), ('hit@10', 0.7391), ('precision@10', 0.1537), ('map@10', 0.0866)]), 'test_result': OrderedDict([('recall@10', 0.1365), ('mrr@10', 0.4322), ('ndcg@10', 0.2182), ('hit@10', 0.7603), ('precision@10', 0.1806), ('map@10', 0.1145)])}
# running NeuMF...
# 26 Dec 16:16    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 16:16    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mf_embedding_size = 64
# mlp_embedding_size = 64
# mlp_hidden_size = [600, 400, 200]
# dropout_prob = 0.1
# mf_train = True
# mlp_train = True
# use_pretrain = False
# mf_pretrain_path = None
# mlp_pretrain_path = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 16:17    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 16:17    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 16:17    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 16:17    INFO  NeuMF(
#   (user_mf_embedding): Embedding(31361, 64)
#   (item_mf_embedding): Embedding(6808, 64)
#   (user_mlp_embedding): Embedding(31361, 64)
#   (item_mlp_embedding): Embedding(6808, 64)
#   (mlp_layers): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=128, out_features=600, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=600, out_features=400, bias=True)
#       (5): ReLU()
#       (6): Dropout(p=0.1, inplace=False)
#       (7): Linear(in_features=400, out_features=200, bias=True)
#       (8): ReLU()
#     )
#   )
#   (predict_layer): Linear(in_features=264, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 5283897
# 26 Dec 16:17    INFO  FLOPs: 397320.0
# 26 Dec 16:17    INFO  epoch 0 training [time: 22.60s, train loss: 1584.6846]
# 26 Dec 16:18    INFO  epoch 0 evaluating [time: 63.74s, valid_score: 0.101100]
# 26 Dec 16:18    INFO  valid result:
# recall@10 : 0.1011    mrr@10 : 0.3284    ndcg@10 : 0.1562    hit@10 : 0.6777    precision@10 : 0.1338    map@10 : 0.0722
# 26 Dec 16:18    INFO  Saving current: saved/NeuMF-Dec-26-2022_16-17-28.pth
# 26 Dec 16:19    INFO  epoch 1 training [time: 23.02s, train loss: 1289.3820]
# 26 Dec 16:20    INFO  epoch 1 evaluating [time: 63.71s, valid_score: 0.107800]
# 26 Dec 16:20    INFO  valid result:
# recall@10 : 0.1078    mrr@10 : 0.3431    ndcg@10 : 0.1651    hit@10 : 0.7019    precision@10 : 0.1414    map@10 : 0.077
# 26 Dec 16:20    INFO  Saving current: saved/NeuMF-Dec-26-2022_16-17-28.pth
# 26 Dec 16:20    INFO  epoch 2 training [time: 22.82s, train loss: 1182.6743]
# 26 Dec 16:21    INFO  epoch 2 evaluating [time: 63.63s, valid_score: 0.108700]
# 26 Dec 16:21    INFO  valid result:
# recall@10 : 0.1087    mrr@10 : 0.3397    ndcg@10 : 0.164    hit@10 : 0.7034    precision@10 : 0.1407    map@10 : 0.076
# 26 Dec 16:21    INFO  Saving current: saved/NeuMF-Dec-26-2022_16-17-28.pth
# 26 Dec 16:22    INFO  epoch 3 training [time: 22.73s, train loss: 1103.6360]
# 26 Dec 16:23    INFO  epoch 3 evaluating [time: 64.01s, valid_score: 0.111900]
# 26 Dec 16:23    INFO  valid result:
# recall@10 : 0.1119    mrr@10 : 0.3491    ndcg@10 : 0.169    hit@10 : 0.7149    precision@10 : 0.1448    map@10 : 0.0787
# 26 Dec 16:23    INFO  Saving current: saved/NeuMF-Dec-26-2022_16-17-28.pth
# 26 Dec 16:23    INFO  epoch 4 training [time: 22.78s, train loss: 1044.6481]
# 26 Dec 16:24    INFO  epoch 4 evaluating [time: 63.96s, valid_score: 0.108500]
# 26 Dec 16:24    INFO  valid result:
# recall@10 : 0.1085    mrr@10 : 0.3375    ndcg@10 : 0.1623    hit@10 : 0.7053    precision@10 : 0.1392    map@10 : 0.0747
# 26 Dec 16:25    INFO  epoch 5 training [time: 22.55s, train loss: 1001.7558]
# 26 Dec 16:26    INFO  epoch 5 evaluating [time: 63.94s, valid_score: 0.109200]
# 26 Dec 16:26    INFO  valid result:
# recall@10 : 0.1092    mrr@10 : 0.3338    ndcg@10 : 0.1616    hit@10 : 0.7046    precision@10 : 0.139    map@10 : 0.0743
# 26 Dec 16:26    INFO  epoch 6 training [time: 22.70s, train loss: 968.0738]
# 26 Dec 16:27    INFO  epoch 6 evaluating [time: 63.77s, valid_score: 0.101700]
# 26 Dec 16:27    INFO  valid result:
# recall@10 : 0.1017    mrr@10 : 0.3074    ndcg@10 : 0.1476    hit@10 : 0.6812    precision@10 : 0.1281    map@10 : 0.0659
# 26 Dec 16:27    INFO  epoch 7 training [time: 22.64s, train loss: 942.8692]
# 26 Dec 16:29    INFO  epoch 7 evaluating [time: 64.43s, valid_score: 0.096700]
# 26 Dec 16:29    INFO  valid result:
# recall@10 : 0.0967    mrr@10 : 0.2918    ndcg@10 : 0.14    hit@10 : 0.6635    precision@10 : 0.1223    map@10 : 0.0618
# 26 Dec 16:29    INFO  epoch 8 training [time: 22.72s, train loss: 920.4935]
# 26 Dec 16:30    INFO  epoch 8 evaluating [time: 63.98s, valid_score: 0.090700]
# 26 Dec 16:30    INFO  valid result:
# recall@10 : 0.0907    mrr@10 : 0.2714    ndcg@10 : 0.1288    hit@10 : 0.6386    precision@10 : 0.1131    map@10 : 0.0554
# 26 Dec 16:30    INFO  epoch 9 training [time: 22.92s, train loss: 903.3225]
# 26 Dec 16:31    INFO  epoch 9 evaluating [time: 64.12s, valid_score: 0.096200]
# 26 Dec 16:31    INFO  valid result:
# recall@10 : 0.0962    mrr@10 : 0.2846    ndcg@10 : 0.1374    hit@10 : 0.6584    precision@10 : 0.1206    map@10 : 0.0602
# 26 Dec 16:32    INFO  epoch 10 training [time: 23.17s, train loss: 889.0565]
# 26 Dec 16:33    INFO  epoch 10 evaluating [time: 63.62s, valid_score: 0.097600]
# 26 Dec 16:33    INFO  valid result:
# recall@10 : 0.0976    mrr@10 : 0.2898    ndcg@10 : 0.14    hit@10 : 0.661    precision@10 : 0.1225    map@10 : 0.0619
# 26 Dec 16:33    INFO  epoch 11 training [time: 22.64s, train loss: 877.1158]
# 26 Dec 16:34    INFO  epoch 11 evaluating [time: 64.29s, valid_score: 0.104500]
# 26 Dec 16:34    INFO  valid result:
# recall@10 : 0.1045    mrr@10 : 0.3062    ndcg@10 : 0.1497    hit@10 : 0.6841    precision@10 : 0.1304    map@10 : 0.0672
# 26 Dec 16:35    INFO  epoch 12 training [time: 23.22s, train loss: 864.0482]
# 26 Dec 16:36    INFO  epoch 12 evaluating [time: 64.20s, valid_score: 0.099100]
# 26 Dec 16:36    INFO  valid result:
# recall@10 : 0.0991    mrr@10 : 0.2878    ndcg@10 : 0.1399    hit@10 : 0.6653    precision@10 : 0.1229    map@10 : 0.0615
# 26 Dec 16:36    INFO  epoch 13 training [time: 22.90s, train loss: 852.6203]
# 26 Dec 16:37    INFO  epoch 13 evaluating [time: 63.90s, valid_score: 0.092100]
# 26 Dec 16:37    INFO  valid result:
# recall@10 : 0.0921    mrr@10 : 0.269    ndcg@10 : 0.1299    hit@10 : 0.6402    precision@10 : 0.1148    map@10 : 0.0561
# 26 Dec 16:38    INFO  epoch 14 training [time: 23.32s, train loss: 843.2628]
# 26 Dec 16:39    INFO  epoch 14 evaluating [time: 64.20s, valid_score: 0.088600]
# 26 Dec 16:39    INFO  valid result:
# recall@10 : 0.0886    mrr@10 : 0.2578    ndcg@10 : 0.1239    hit@10 : 0.624    precision@10 : 0.1098    map@10 : 0.053
# 26 Dec 16:39    INFO  Finished training, best eval result in epoch 3
# 26 Dec 16:39    INFO  Loading model structure and parameters from saved/NeuMF-Dec-26-2022_16-17-28.pth
# 26 Dec 16:40    INFO  best valid : OrderedDict([('recall@10', 0.1119), ('mrr@10', 0.3491), ('ndcg@10', 0.169), ('hit@10', 0.7149), ('precision@10', 0.1448), ('map@10', 0.0787)])
# 26 Dec 16:40    INFO  test result: OrderedDict([('recall@10', 0.1245), ('mrr@10', 0.4052), ('ndcg@10', 0.2019), ('hit@10', 0.7391), ('precision@10', 0.1697), ('map@10', 0.1032)])
# It took 23.56 mins
# {'best_valid_score': 0.1119, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1119), ('mrr@10', 0.3491), ('ndcg@10', 0.169), ('hit@10', 0.7149), ('precision@10', 0.1448), ('map@10', 0.0787)]), 'test_result': OrderedDict([('recall@10', 0.1245), ('mrr@10', 0.4052), ('ndcg@10', 0.2019), ('hit@10', 0.7391), ('precision@10', 0.1697), ('map@10', 0.1032)])}
# running MultiDAE...
# 26 Dec 16:40    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 16:40    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600, 400, 200]
# latent_dimension = 64
# dropout_prob = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 16:40    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 16:41    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 16:41    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 16:41    WARNING  Max value of user's history interaction records has reached 34.22444183313749% of the total.
# 26 Dec 16:41    INFO  MultiDAE(
#   (encoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=6808, out_features=600, bias=True)
#       (2): Tanh()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): Linear(in_features=600, out_features=400, bias=True)
#       (5): Tanh()
#       (6): Dropout(p=0.0, inplace=False)
#       (7): Linear(in_features=400, out_features=200, bias=True)
#       (8): Tanh()
#       (9): Dropout(p=0.0, inplace=False)
#       (10): Linear(in_features=200, out_features=64, bias=True)
#       (11): Tanh()
#     )
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=200, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=200, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=600, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=600, out_features=6808, bias=True)
#   )
# )
# Trainable parameters: 8844472
# 26 Dec 16:41    INFO  FLOPs: 8835200.0
# 26 Dec 16:41    INFO  epoch 0 training [time: 0.20s, train loss: 17092.4449]
# 26 Dec 16:42    INFO  epoch 0 evaluating [time: 49.50s, valid_score: 0.077300]
# 26 Dec 16:42    INFO  valid result:
# recall@10 : 0.0773    mrr@10 : 0.2722    ndcg@10 : 0.1208    hit@10 : 0.5661    precision@10 : 0.1001    map@10 : 0.0543
# 26 Dec 16:42    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:42    INFO  epoch 1 training [time: 0.20s, train loss: 16412.5986]
# 26 Dec 16:42    INFO  epoch 1 evaluating [time: 49.07s, valid_score: 0.079000]
# 26 Dec 16:42    INFO  valid result:
# recall@10 : 0.079    mrr@10 : 0.2753    ndcg@10 : 0.123    hit@10 : 0.5709    precision@10 : 0.1019    map@10 : 0.0555
# 26 Dec 16:42    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:42    INFO  epoch 2 training [time: 0.20s, train loss: 16393.6307]
# 26 Dec 16:43    INFO  epoch 2 evaluating [time: 49.43s, valid_score: 0.079900]
# 26 Dec 16:43    INFO  valid result:
# recall@10 : 0.0799    mrr@10 : 0.2763    ndcg@10 : 0.1241    hit@10 : 0.5732    precision@10 : 0.1028    map@10 : 0.0563
# 26 Dec 16:43    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:43    INFO  epoch 3 training [time: 0.20s, train loss: 16358.9063]
# 26 Dec 16:44    INFO  epoch 3 evaluating [time: 49.88s, valid_score: 0.080200]
# 26 Dec 16:44    INFO  valid result:
# recall@10 : 0.0802    mrr@10 : 0.2772    ndcg@10 : 0.1245    hit@10 : 0.5751    precision@10 : 0.1035    map@10 : 0.0564
# 26 Dec 16:44    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:44    INFO  epoch 4 training [time: 0.20s, train loss: 16238.7051]
# 26 Dec 16:45    INFO  epoch 4 evaluating [time: 49.74s, valid_score: 0.081400]
# 26 Dec 16:45    INFO  valid result:
# recall@10 : 0.0814    mrr@10 : 0.274    ndcg@10 : 0.1238    hit@10 : 0.5777    precision@10 : 0.1034    map@10 : 0.0557
# 26 Dec 16:45    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:45    INFO  epoch 5 training [time: 0.20s, train loss: 16133.5211]
# 26 Dec 16:46    INFO  epoch 5 evaluating [time: 49.50s, valid_score: 0.082600]
# 26 Dec 16:46    INFO  valid result:
# recall@10 : 0.0826    mrr@10 : 0.2778    ndcg@10 : 0.126    hit@10 : 0.5868    precision@10 : 0.1055    map@10 : 0.0568
# 26 Dec 16:46    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:46    INFO  epoch 6 training [time: 0.21s, train loss: 16151.6243]
# 26 Dec 16:47    INFO  epoch 6 evaluating [time: 49.87s, valid_score: 0.085100]
# 26 Dec 16:47    INFO  valid result:
# recall@10 : 0.0851    mrr@10 : 0.2848    ndcg@10 : 0.1301    hit@10 : 0.5949    precision@10 : 0.1088    map@10 : 0.0593
# 26 Dec 16:47    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:47    INFO  epoch 7 training [time: 0.20s, train loss: 16111.7024]
# 26 Dec 16:47    INFO  epoch 7 evaluating [time: 49.67s, valid_score: 0.086400]
# 26 Dec 16:47    INFO  valid result:
# recall@10 : 0.0864    mrr@10 : 0.286    ndcg@10 : 0.1308    hit@10 : 0.5963    precision@10 : 0.1093    map@10 : 0.0595
# 26 Dec 16:47    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:47    INFO  epoch 8 training [time: 0.20s, train loss: 16106.0427]
# 26 Dec 16:48    INFO  epoch 8 evaluating [time: 49.74s, valid_score: 0.088300]
# 26 Dec 16:48    INFO  valid result:
# recall@10 : 0.0883    mrr@10 : 0.2911    ndcg@10 : 0.1341    hit@10 : 0.6067    precision@10 : 0.1125    map@10 : 0.0612
# 26 Dec 16:48    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:48    INFO  epoch 9 training [time: 0.20s, train loss: 16041.3859]
# 26 Dec 16:49    INFO  epoch 9 evaluating [time: 49.79s, valid_score: 0.090300]
# 26 Dec 16:49    INFO  valid result:
# recall@10 : 0.0903    mrr@10 : 0.3002    ndcg@10 : 0.1388    hit@10 : 0.6136    precision@10 : 0.1162    map@10 : 0.064
# 26 Dec 16:49    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:49    INFO  epoch 10 training [time: 0.20s, train loss: 15894.5777]
# 26 Dec 16:50    INFO  epoch 10 evaluating [time: 50.27s, valid_score: 0.093700]
# 26 Dec 16:50    INFO  valid result:
# recall@10 : 0.0937    mrr@10 : 0.308    ndcg@10 : 0.1428    hit@10 : 0.6343    precision@10 : 0.1201    map@10 : 0.0656
# 26 Dec 16:50    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:50    INFO  epoch 11 training [time: 0.20s, train loss: 15844.9519]
# 26 Dec 16:51    INFO  epoch 11 evaluating [time: 50.36s, valid_score: 0.095600]
# 26 Dec 16:51    INFO  valid result:
# recall@10 : 0.0956    mrr@10 : 0.3135    ndcg@10 : 0.1465    hit@10 : 0.6421    precision@10 : 0.1232    map@10 : 0.0678
# 26 Dec 16:51    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:51    INFO  epoch 12 training [time: 0.20s, train loss: 15775.7745]
# 26 Dec 16:52    INFO  epoch 12 evaluating [time: 50.37s, valid_score: 0.097100]
# 26 Dec 16:52    INFO  valid result:
# recall@10 : 0.0971    mrr@10 : 0.3161    ndcg@10 : 0.1479    hit@10 : 0.6489    precision@10 : 0.1245    map@10 : 0.0683
# 26 Dec 16:52    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:52    INFO  epoch 13 training [time: 0.20s, train loss: 15750.5923]
# 26 Dec 16:52    INFO  epoch 13 evaluating [time: 50.48s, valid_score: 0.098200]
# 26 Dec 16:52    INFO  valid result:
# recall@10 : 0.0982    mrr@10 : 0.3179    ndcg@10 : 0.1491    hit@10 : 0.6562    precision@10 : 0.1258    map@10 : 0.0688
# 26 Dec 16:52    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:52    INFO  epoch 14 training [time: 0.19s, train loss: 15629.4472]
# 26 Dec 16:53    INFO  epoch 14 evaluating [time: 50.46s, valid_score: 0.100100]
# 26 Dec 16:53    INFO  valid result:
# recall@10 : 0.1001    mrr@10 : 0.3234    ndcg@10 : 0.1521    hit@10 : 0.6612    precision@10 : 0.1282    map@10 : 0.0706
# 26 Dec 16:53    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:53    INFO  epoch 15 training [time: 0.20s, train loss: 15595.1973]
# 26 Dec 16:54    INFO  epoch 15 evaluating [time: 50.66s, valid_score: 0.100600]
# 26 Dec 16:54    INFO  valid result:
# recall@10 : 0.1006    mrr@10 : 0.3228    ndcg@10 : 0.1519    hit@10 : 0.6621    precision@10 : 0.128    map@10 : 0.0703
# 26 Dec 16:54    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:54    INFO  epoch 16 training [time: 0.20s, train loss: 15589.0812]
# 26 Dec 16:55    INFO  epoch 16 evaluating [time: 50.13s, valid_score: 0.102400]
# 26 Dec 16:55    INFO  valid result:
# recall@10 : 0.1024    mrr@10 : 0.3288    ndcg@10 : 0.1555    hit@10 : 0.671    precision@10 : 0.1313    map@10 : 0.0723
# 26 Dec 16:55    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:55    INFO  epoch 17 training [time: 0.19s, train loss: 15539.6021]
# 26 Dec 16:56    INFO  epoch 17 evaluating [time: 50.33s, valid_score: 0.102900]
# 26 Dec 16:56    INFO  valid result:
# recall@10 : 0.1029    mrr@10 : 0.33    ndcg@10 : 0.1557    hit@10 : 0.672    precision@10 : 0.1313    map@10 : 0.0723
# 26 Dec 16:56    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:56    INFO  epoch 18 training [time: 0.19s, train loss: 15515.9548]
# 26 Dec 16:57    INFO  epoch 18 evaluating [time: 51.05s, valid_score: 0.105700]
# 26 Dec 16:57    INFO  valid result:
# recall@10 : 0.1057    mrr@10 : 0.3334    ndcg@10 : 0.1584    hit@10 : 0.6813    precision@10 : 0.1337    map@10 : 0.0737
# 26 Dec 16:57    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:57    INFO  epoch 19 training [time: 0.20s, train loss: 15435.2382]
# 26 Dec 16:58    INFO  epoch 19 evaluating [time: 50.89s, valid_score: 0.107000]
# 26 Dec 16:58    INFO  valid result:
# recall@10 : 0.107    mrr@10 : 0.3394    ndcg@10 : 0.1616    hit@10 : 0.6871    precision@10 : 0.1364    map@10 : 0.0756
# 26 Dec 16:58    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:58    INFO  epoch 20 training [time: 0.20s, train loss: 15441.6063]
# 26 Dec 16:58    INFO  epoch 20 evaluating [time: 50.93s, valid_score: 0.106900]
# 26 Dec 16:58    INFO  valid result:
# recall@10 : 0.1069    mrr@10 : 0.3362    ndcg@10 : 0.1605    hit@10 : 0.6881    precision@10 : 0.1358    map@10 : 0.0748
# 26 Dec 16:58    INFO  epoch 21 training [time: 0.20s, train loss: 15399.4028]
# 26 Dec 16:59    INFO  epoch 21 evaluating [time: 50.36s, valid_score: 0.108500]
# 26 Dec 16:59    INFO  valid result:
# recall@10 : 0.1085    mrr@10 : 0.3454    ndcg@10 : 0.1646    hit@10 : 0.6945    precision@10 : 0.1387    map@10 : 0.0774
# 26 Dec 16:59    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 16:59    INFO  epoch 22 training [time: 0.20s, train loss: 15353.1205]
# 26 Dec 17:00    INFO  epoch 22 evaluating [time: 50.26s, valid_score: 0.109300]
# 26 Dec 17:00    INFO  valid result:
# recall@10 : 0.1093    mrr@10 : 0.3486    ndcg@10 : 0.1662    hit@10 : 0.6971    precision@10 : 0.1399    map@10 : 0.0782
# 26 Dec 17:00    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:00    INFO  epoch 23 training [time: 0.20s, train loss: 15389.6605]
# 26 Dec 17:01    INFO  epoch 23 evaluating [time: 51.03s, valid_score: 0.110700]
# 26 Dec 17:01    INFO  valid result:
# recall@10 : 0.1107    mrr@10 : 0.3478    ndcg@10 : 0.1663    hit@10 : 0.6995    precision@10 : 0.1401    map@10 : 0.078
# 26 Dec 17:01    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:01    INFO  epoch 24 training [time: 0.20s, train loss: 15350.6366]
# 26 Dec 17:02    INFO  epoch 24 evaluating [time: 49.94s, valid_score: 0.113500]
# 26 Dec 17:02    INFO  valid result:
# recall@10 : 0.1135    mrr@10 : 0.3566    ndcg@10 : 0.1716    hit@10 : 0.7078    precision@10 : 0.1444    map@10 : 0.0814
# 26 Dec 17:02    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:02    INFO  epoch 25 training [time: 0.21s, train loss: 15236.8109]
# 26 Dec 17:03    INFO  epoch 25 evaluating [time: 49.83s, valid_score: 0.115500]
# 26 Dec 17:03    INFO  valid result:
# recall@10 : 0.1155    mrr@10 : 0.3619    ndcg@10 : 0.1747    hit@10 : 0.7143    precision@10 : 0.1468    map@10 : 0.0831
# 26 Dec 17:03    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:03    INFO  epoch 26 training [time: 0.20s, train loss: 15262.4770]
# 26 Dec 17:04    INFO  epoch 26 evaluating [time: 50.00s, valid_score: 0.115700]
# 26 Dec 17:04    INFO  valid result:
# recall@10 : 0.1157    mrr@10 : 0.3597    ndcg@10 : 0.1739    hit@10 : 0.7153    precision@10 : 0.1465    map@10 : 0.0826
# 26 Dec 17:04    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:04    INFO  epoch 27 training [time: 0.20s, train loss: 15247.4539]
# 26 Dec 17:04    INFO  epoch 27 evaluating [time: 49.95s, valid_score: 0.117900]
# 26 Dec 17:04    INFO  valid result:
# recall@10 : 0.1179    mrr@10 : 0.3657    ndcg@10 : 0.1779    hit@10 : 0.7228    precision@10 : 0.15    map@10 : 0.0849
# 26 Dec 17:04    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:04    INFO  epoch 28 training [time: 0.20s, train loss: 15227.2806]
# 26 Dec 17:05    INFO  epoch 28 evaluating [time: 49.75s, valid_score: 0.118000]
# 26 Dec 17:05    INFO  valid result:
# recall@10 : 0.118    mrr@10 : 0.3591    ndcg@10 : 0.175    hit@10 : 0.7213    precision@10 : 0.148    map@10 : 0.0829
# 26 Dec 17:05    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:05    INFO  epoch 29 training [time: 0.20s, train loss: 15196.8625]
# 26 Dec 17:06    INFO  epoch 29 evaluating [time: 50.26s, valid_score: 0.120700]
# 26 Dec 17:06    INFO  valid result:
# recall@10 : 0.1207    mrr@10 : 0.3699    ndcg@10 : 0.1803    hit@10 : 0.7344    precision@10 : 0.1523    map@10 : 0.0858
# 26 Dec 17:06    INFO  Saving current: saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:06    INFO  Loading model structure and parameters from saved/MultiDAE-Dec-26-2022_16-41-12.pth
# 26 Dec 17:07    INFO  best valid : OrderedDict([('recall@10', 0.1207), ('mrr@10', 0.3699), ('ndcg@10', 0.1803), ('hit@10', 0.7344), ('precision@10', 0.1523), ('map@10', 0.0858)])
# 26 Dec 17:07    INFO  test result: OrderedDict([('recall@10', 0.1349), ('mrr@10', 0.4294), ('ndcg@10', 0.2154), ('hit@10', 0.7584), ('precision@10', 0.1778), ('map@10', 0.1125)])
# It took 27.11 mins
# {'best_valid_score': 0.1207, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1207), ('mrr@10', 0.3699), ('ndcg@10', 0.1803), ('hit@10', 0.7344), ('precision@10', 0.1523), ('map@10', 0.0858)]), 'test_result': OrderedDict([('recall@10', 0.1349), ('mrr@10', 0.4294), ('ndcg@10', 0.2154), ('hit@10', 0.7584), ('precision@10', 0.1778), ('map@10', 0.1125)])}
# running CDAE...
# 26 Dec 17:07    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 17:07    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# loss_type = BCE
# hid_activation = relu
# out_activation = sigmoid
# corruption_ratio = 0.5
# embedding_size = 64
# reg_weight_1 = 0.0
# reg_weight_2 = 0.01
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# mlp_hidden_size = [600, 400, 200]
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# ...
# 26 Dec 17:58    INFO  Saving current: saved/RecVAE-Dec-26-2022_17-29-36.pth
# 26 Dec 17:58    INFO  epoch 29 training [time: 1.00s, train loss: 10179.6672]
# 26 Dec 17:59    INFO  epoch 29 evaluating [time: 59.03s, valid_score: 0.145700]
# 26 Dec 17:59    INFO  valid result:
# recall@10 : 0.1457    mrr@10 : 0.4278    ndcg@10 : 0.2174    hit@10 : 0.7997    precision@10 : 0.1822    map@10 : 0.1084
# 26 Dec 17:59    INFO  Saving current: saved/RecVAE-Dec-26-2022_17-29-36.pth
# 26 Dec 17:59    INFO  Loading model structure and parameters from saved/RecVAE-Dec-26-2022_17-29-36.pth
# 26 Dec 18:00    INFO  best valid : OrderedDict([('recall@10', 0.1457), ('mrr@10', 0.4278), ('ndcg@10', 0.2174), ('hit@10', 0.7997), ('precision@10', 0.1822), ('map@10', 0.1084)])
# 26 Dec 18:00    INFO  test result: OrderedDict([('recall@10', 0.166), ('mrr@10', 0.5118), ('ndcg@10', 0.2683), ('hit@10', 0.8247), ('precision@10', 0.2192), ('map@10', 0.1496)])
# It took 32.12 mins
# {'best_valid_score': 0.1457, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1457), ('mrr@10', 0.4278), ('ndcg@10', 0.2174), ('hit@10', 0.7997), ('precision@10', 0.1822), ('map@10', 0.1084)]), 'test_result': OrderedDict([('recall@10', 0.166), ('mrr@10', 0.5118), ('ndcg@10', 0.2683), ('hit@10', 0.8247), ('precision@10', 0.2192), ('map@10', 0.1496)])}
# running EASE...
# 26 Dec 18:00    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 18:00    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# reg_weight = 250.0
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# device = cuda
# mlp_hidden_size = [600, 400, 200]
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 18:01    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 18:01    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 18:01    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 18:01    INFO  EASE()
# Trainable parameters: 1
# 26 Dec 18:01    INFO  FLOPs: 0.0
# 26 Dec 18:01    INFO  epoch 0 training [time: 9.87s, train loss: 0.0000]
# 26 Dec 18:02    INFO  epoch 0 evaluating [time: 53.92s, valid_score: 0.164400]
# 26 Dec 18:02    INFO  valid result:
# recall@10 : 0.1644    mrr@10 : 0.4709    ndcg@10 : 0.2437    hit@10 : 0.8396    precision@10 : 0.2025    map@10 : 0.1248
# 26 Dec 18:02    INFO  Saving current: saved/EASE-Dec-26-2022_18-01-48.pth
# 26 Dec 18:02    INFO  Loading model structure and parameters from saved/EASE-Dec-26-2022_18-01-48.pth
# 26 Dec 18:03    INFO  best valid : OrderedDict([('recall@10', 0.1644), ('mrr@10', 0.4709), ('ndcg@10', 0.2437), ('hit@10', 0.8396), ('precision@10', 0.2025), ('map@10', 0.1248)])
# 26 Dec 18:03    INFO  test result: OrderedDict([('recall@10', 0.1886), ('mrr@10', 0.5723), ('ndcg@10', 0.3056), ('hit@10', 0.8628), ('precision@10', 0.2459), ('map@10', 0.1764)])
# It took 2.99 mins
# {'best_valid_score': 0.1644, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1644), ('mrr@10', 0.4709), ('ndcg@10', 0.2437), ('hit@10', 0.8396), ('precision@10', 0.2025), ('map@10', 0.1248)]), 'test_result': OrderedDict([('recall@10', 0.1886), ('mrr@10', 0.5723), ('ndcg@10', 0.3056), ('hit@10', 0.8628), ('precision@10', 0.2459), ('map@10', 0.1764)])}
# running SLIMElastic...
# 26 Dec 18:03    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 18:03    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# alpha = 0.2
# l1_ratio = 0.02
# positive_only = True
# hide_item = True
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# device = cuda
# mlp_hidden_size = [600, 400, 200]
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 18:04    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 18:04    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 18:04    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 19:52    INFO  SLIMElastic()
# Trainable parameters: 1
# 26 Dec 19:52    INFO  FLOPs: 0.0
# 26 Dec 19:52    INFO  epoch 0 training [time: 10.02s, train loss: 0.0000]
# 26 Dec 19:54    INFO  epoch 0 evaluating [time: 92.75s, valid_score: 0.149300]
# 26 Dec 19:54    INFO  valid result:
# recall@10 : 0.1493    mrr@10 : 0.4546    ndcg@10 : 0.2263    hit@10 : 0.8078    precision@10 : 0.1852    map@10 : 0.1145
# 26 Dec 19:54    INFO  Saving current: saved/SLIMElastic-Dec-26-2022_19-52-41.pth
# 26 Dec 19:54    INFO  Loading model structure and parameters from saved/SLIMElastic-Dec-26-2022_19-52-41.pth
# 26 Dec 19:56    INFO  best valid : OrderedDict([('recall@10', 0.1493), ('mrr@10', 0.4546), ('ndcg@10', 0.2263), ('hit@10', 0.8078), ('precision@10', 0.1852), ('map@10', 0.1145)])
# 26 Dec 19:56    INFO  test result: OrderedDict([('recall@10', 0.1699), ('mrr@10', 0.5464), ('ndcg@10', 0.2797), ('hit@10', 0.833), ('precision@10', 0.2215), ('map@10', 0.1579)])
# It took 112.28 mins
# {'best_valid_score': 0.1493, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1493), ('mrr@10', 0.4546), ('ndcg@10', 0.2263), ('hit@10', 0.8078), ('precision@10', 0.1852), ('map@10', 0.1145)]), 'test_result': OrderedDict([('recall@10', 0.1699), ('mrr@10', 0.5464), ('ndcg@10', 0.2797), ('hit@10', 0.833), ('precision@10', 0.2215), ('map@10', 0.1579)])}
# running ADMMSLIM...
# 26 Dec 19:56    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9018', '--control=9016', '--hb=9015', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"499b6bdb-a389-4f27-ae92-17c23ffbdec9"', '--shell=9017', '--transport="tcp"', '--iopub=9019', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-34931OI93FR56AwQR.json']
# 26 Dec 19:56    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# lambda1 = 3.0
# lambda2 = 200.0
# alpha = 0.5
# rho = 4000.0
# k = 100
# positive_only = True
# center_columns = False
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# device = cuda
# mlp_hidden_size = [600, 400, 200]
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 26 Dec 19:56    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 26 Dec 19:56    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 26 Dec 19:56    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [8, 1, 1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 26 Dec 20:07    INFO  ADMMSLIM()
# Trainable parameters: 1
# 26 Dec 20:07    INFO  FLOPs: 0.0
# 26 Dec 20:07    INFO  epoch 0 training [time: 9.85s, train loss: 0.0000]
# 26 Dec 20:11    INFO  epoch 0 evaluating [time: 245.11s, valid_score: 0.164900]
# 26 Dec 20:11    INFO  valid result:
# recall@10 : 0.1649    mrr@10 : 0.4762    ndcg@10 : 0.2473    hit@10 : 0.8431    precision@10 : 0.2058    map@10 : 0.1274
# 26 Dec 20:11    INFO  Saving current: saved/ADMMSLIM-Dec-26-2022_20-07-18.pth
# 26 Dec 20:11    INFO  Loading model structure and parameters from saved/ADMMSLIM-Dec-26-2022_20-07-18.pth
# 26 Dec 20:15    INFO  best valid : OrderedDict([('recall@10', 0.1649), ('mrr@10', 0.4762), ('ndcg@10', 0.2473), ('hit@10', 0.8431), ('precision@10', 0.2058), ('map@10', 0.1274)])
# 26 Dec 20:15    INFO  test result: OrderedDict([('recall@10', 0.1896), ('mrr@10', 0.5797), ('ndcg@10', 0.3124), ('hit@10', 0.8618), ('precision@10', 0.2517), ('map@10', 0.1833)])
# It took 19.62 mins
# {'best_valid_score': 0.1649, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1649), ('mrr@10', 0.4762), ('ndcg@10', 0.2473), ('hit@10', 0.8431), ('precision@10', 0.2058), ('map@10', 0.1274)]), 'test_result': OrderedDict([('recall@10', 0.1896), ('mrr@10', 0.5797), ('ndcg@10', 0.3124), ('hit@10', 0.8618), ('precision@10', 0.2517), ('map@10', 0.1833)])}
