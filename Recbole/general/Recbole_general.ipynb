# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

import os
import json
import argparse
import pandas as pd
import numpy as np
import time, datetime
from tqdm import tqdm
from logging import getLogger
import torch

from recbole.quick_start import run_recbole
import wandb

# %%
# train load
train = pd.read_csv("/opt/ml/input/data/train/train_ratings.csv")

# indexing save
user2idx = {v:k for k,v in enumerate(sorted(set(train.user)))}
item2idx = {v:k for k,v in enumerate(sorted(set(train.item)))}
uidx2user = {k:v for k,v in enumerate(sorted(set(train.user)))}
iidx2item = {k:v for k,v in enumerate(sorted(set(train.item)))}

# %%
train.user = train.user.map(user2idx)
train.item = train.item.map(item2idx)

train.columns=['user_id:token','item_id:token','timestamp:float']

outpath = f"dataset/train_data"
os.makedirs(outpath, exist_ok=True)
# sub_train=train.groupby("user").sample(n=10, random_state=SEED)
# sub_train.shape
train.to_csv(os.path.join(outpath,"train_data.inter"),sep='\t',index=False)

# %%
yamldata="""
USER_ID_FIELD: user_id
ITEM_ID_FIELD: item_id
TIME_FIELD: timestamp

load_col:
    inter: [user_id, item_id, timestamp]

show_progress : False
epochs : 10
device : torch.device("cuda" if torch.cuda.is_available() else "cpu")
eval_args:
    split: {'RS': [9, 1, 0]}
    group_by: user
    order: RO
    mode: full
metrics: ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
topk: 10
valid_metric: Recall@10

log_wandb : True
wandb_project : Recbole

mlp_hidden_size : [600,400,200]
"""
with open("general.yaml", "w") as f:
    f.write(yamldata)
# Out:
# 484

# %%
def run(model_name):
    if model_name in [
        "MultiVAE",
        "MultiDAE",
        "MacridVAE",
        "RecVAE",
        "GRU4Rec",
        "NARM",
        "STAMP",
        "NextItNet",
        "TransRec",
        "SASRec",
        "BERT4Rec",
        "SRGNN",
        "GCSAN",
        "GRU4RecF",
        "FOSSIL",
        "SHAN",
        "RepeatNet",
        "HRM",
        "NPE",
    ]:
        parameter_dict = {
            "neg_sampling": None,
        }
        return run_recbole(
            model=model_name,
            dataset='train_data',
            config_file_list=['general.yaml'],
            config_dict=parameter_dict,
        )
    else:
        return run_recbole(
            model=model_name,
            dataset='train_data',
            config_file_list=['general.yaml'],
        )

# %%
model_list = ['MultiVAE','MultiDAE'] # 해당 리스트에 쓰고 싶은 모델을 넣어줍니다.
os.environ['WANDB_NOTEBOOK_NAME'] = '/opt/ml/input/MR/Recbole/general/Recbole_general.ipynb'
for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run(model_name)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
    wandb.run.finish()
# Out:
# running MultiVAE...
# 27 Dec 05:17    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9008', '--control=9006', '--hb=9005', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"7fd8b746-1a87-4b32-97c0-fccd01819acb"', '--shell=9007', '--transport="tcp"', '--iopub=9009', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-48980F7V0o03cn7e6.json']
# 27 Dec 05:17    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 1, 0]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600, 400, 200]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 27 Dec 05:18    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 27 Dec 05:18    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 27 Dec 05:18    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 1, 0]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 27 Dec 05:18    WARNING  Max value of user's history interaction records has reached 38.49882491186839% of the total.
# 27 Dec 05:18    INFO  MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=6808, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=200, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=200, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=200, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=200, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=600, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=600, out_features=6808, bias=True)
#   )
# )
# Trainable parameters: 8857336
# 27 Dec 05:18    INFO  FLOPs: 8848000.0
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find uijoon.
# wandb: Currently logged in as: ujoon (recsys8). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/opt/ml/input/MR/Recbole/general/wandb/run-20221227_051836-5td1kqi2</code>
# Syncing run <strong><a href="https://wandb.ai/recsys8/Recbole/runs/5td1kqi2" target="_blank">laced-dust-4</a></strong> to <a href="https://wandb.ai/recsys8/Recbole" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 27 Dec 05:18    INFO  epoch 0 training [time: 0.22s, train loss: 19151.7617]
# 27 Dec 05:19    INFO  epoch 0 evaluating [time: 49.00s, valid_score: 0.085700]
# 27 Dec 05:19    INFO  valid result:
# recall@10 : 0.0857    mrr@10 : 0.2913    ndcg@10 : 0.1364    hit@10 : 0.5899    precision@10 : 0.1146    map@10 : 0.0644
# 27 Dec 05:19    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:19    INFO  epoch 1 training [time: 0.21s, train loss: 18392.2695]
# 27 Dec 05:20    INFO  epoch 1 evaluating [time: 48.13s, valid_score: 0.084500]
# 27 Dec 05:20    INFO  valid result:
# recall@10 : 0.0845    mrr@10 : 0.2989    ndcg@10 : 0.1373    hit@10 : 0.5878    precision@10 : 0.1135    map@10 : 0.0653
# 27 Dec 05:20    INFO  epoch 2 training [time: 0.21s, train loss: 18375.4537]
# 27 Dec 05:21    INFO  epoch 2 evaluating [time: 49.35s, valid_score: 0.087300]
# 27 Dec 05:21    INFO  valid result:
# recall@10 : 0.0873    mrr@10 : 0.3115    ndcg@10 : 0.1427    hit@10 : 0.5926    precision@10 : 0.1167    map@10 : 0.069
# 27 Dec 05:21    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:21    INFO  epoch 3 training [time: 0.20s, train loss: 18370.0396]
# 27 Dec 05:21    INFO  epoch 3 evaluating [time: 49.71s, valid_score: 0.086500]
# 27 Dec 05:21    INFO  valid result:
# recall@10 : 0.0865    mrr@10 : 0.3103    ndcg@10 : 0.1413    hit@10 : 0.5941    precision@10 : 0.1156    map@10 : 0.0679
# 27 Dec 05:21    INFO  epoch 4 training [time: 0.21s, train loss: 18288.6401]
# 27 Dec 05:22    INFO  epoch 4 evaluating [time: 49.79s, valid_score: 0.087500]
# 27 Dec 05:22    INFO  valid result:
# recall@10 : 0.0875    mrr@10 : 0.3088    ndcg@10 : 0.141    hit@10 : 0.5946    precision@10 : 0.1155    map@10 : 0.0676
# 27 Dec 05:22    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:22    INFO  epoch 5 training [time: 0.21s, train loss: 18118.1344]
# 27 Dec 05:23    INFO  epoch 5 evaluating [time: 49.16s, valid_score: 0.089500]
# 27 Dec 05:23    INFO  valid result:
# recall@10 : 0.0895    mrr@10 : 0.3126    ndcg@10 : 0.1423    hit@10 : 0.6077    precision@10 : 0.1168    map@10 : 0.0677
# 27 Dec 05:23    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:23    INFO  epoch 6 training [time: 0.21s, train loss: 18112.6976]
# 27 Dec 05:24    INFO  epoch 6 evaluating [time: 49.49s, valid_score: 0.092800]
# 27 Dec 05:24    INFO  valid result:
# recall@10 : 0.0928    mrr@10 : 0.3201    ndcg@10 : 0.1484    hit@10 : 0.616    precision@10 : 0.1222    map@10 : 0.0718
# 27 Dec 05:24    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:24    INFO  epoch 7 training [time: 0.20s, train loss: 18040.9178]
# 27 Dec 05:25    INFO  epoch 7 evaluating [time: 51.34s, valid_score: 0.094600]
# 27 Dec 05:25    INFO  valid result:
# recall@10 : 0.0946    mrr@10 : 0.3294    ndcg@10 : 0.1528    hit@10 : 0.621    precision@10 : 0.125    map@10 : 0.0747
# 27 Dec 05:25    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:25    INFO  epoch 8 training [time: 0.21s, train loss: 18038.2308]
# 27 Dec 05:26    INFO  epoch 8 evaluating [time: 48.97s, valid_score: 0.096700]
# 27 Dec 05:26    INFO  valid result:
# recall@10 : 0.0967    mrr@10 : 0.3347    ndcg@10 : 0.1568    hit@10 : 0.6277    precision@10 : 0.1287    map@10 : 0.0772
# 27 Dec 05:26    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:26    INFO  epoch 9 training [time: 0.20s, train loss: 17955.8215]
# 27 Dec 05:26    INFO  epoch 9 evaluating [time: 49.00s, valid_score: 0.100000]
# 27 Dec 05:26    INFO  valid result:
# recall@10 : 0.1    mrr@10 : 0.3465    ndcg@10 : 0.1639    hit@10 : 0.643    precision@10 : 0.1349    map@10 : 0.0816
# 27 Dec 05:26    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:26    INFO  epoch 10 training [time: 0.21s, train loss: 17807.6382]
# 27 Dec 05:27    INFO  epoch 10 evaluating [time: 49.04s, valid_score: 0.104000]
# 27 Dec 05:27    INFO  valid result:
# recall@10 : 0.104    mrr@10 : 0.3577    ndcg@10 : 0.1701    hit@10 : 0.6632    precision@10 : 0.1405    map@10 : 0.0849
# 27 Dec 05:27    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:27    INFO  epoch 11 training [time: 0.20s, train loss: 17733.8662]
# 27 Dec 05:28    INFO  epoch 11 evaluating [time: 49.59s, valid_score: 0.107000]
# 27 Dec 05:28    INFO  valid result:
# recall@10 : 0.107    mrr@10 : 0.3617    ndcg@10 : 0.1725    hit@10 : 0.6699    precision@10 : 0.1422    map@10 : 0.0862
# 27 Dec 05:28    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:28    INFO  epoch 12 training [time: 0.20s, train loss: 17658.0397]
# 27 Dec 05:29    INFO  epoch 12 evaluating [time: 48.92s, valid_score: 0.108600]
# 27 Dec 05:29    INFO  valid result:
# recall@10 : 0.1086    mrr@10 : 0.3672    ndcg@10 : 0.1759    hit@10 : 0.6786    precision@10 : 0.1454    map@10 : 0.0881
# 27 Dec 05:29    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:29    INFO  epoch 13 training [time: 0.20s, train loss: 17600.7284]
# 27 Dec 05:30    INFO  epoch 13 evaluating [time: 48.21s, valid_score: 0.108500]
# 27 Dec 05:30    INFO  valid result:
# recall@10 : 0.1085    mrr@10 : 0.3609    ndcg@10 : 0.1725    hit@10 : 0.6772    precision@10 : 0.1428    map@10 : 0.0854
# 27 Dec 05:30    INFO  epoch 14 training [time: 0.20s, train loss: 17485.0394]
# 27 Dec 05:31    INFO  epoch 14 evaluating [time: 47.99s, valid_score: 0.112300]
# 27 Dec 05:31    INFO  valid result:
# recall@10 : 0.1123    mrr@10 : 0.3732    ndcg@10 : 0.1797    hit@10 : 0.6904    precision@10 : 0.1485    map@10 : 0.0901
# 27 Dec 05:31    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:31    INFO  epoch 15 training [time: 0.21s, train loss: 17458.0621]
# 27 Dec 05:31    INFO  epoch 15 evaluating [time: 48.27s, valid_score: 0.113800]
# 27 Dec 05:31    INFO  valid result:
# recall@10 : 0.1138    mrr@10 : 0.3848    ndcg@10 : 0.1846    hit@10 : 0.6977    precision@10 : 0.1518    map@10 : 0.0933
# 27 Dec 05:31    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:31    INFO  epoch 16 training [time: 0.20s, train loss: 17452.7717]
# 27 Dec 05:32    INFO  epoch 16 evaluating [time: 47.94s, valid_score: 0.114400]
# 27 Dec 05:32    INFO  valid result:
# recall@10 : 0.1144    mrr@10 : 0.3862    ndcg@10 : 0.186    hit@10 : 0.6998    precision@10 : 0.1531    map@10 : 0.0943
# 27 Dec 05:32    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:32    INFO  epoch 17 training [time: 0.20s, train loss: 17405.3403]
# 27 Dec 05:33    INFO  epoch 17 evaluating [time: 48.74s, valid_score: 0.115600]
# 27 Dec 05:33    INFO  valid result:
# recall@10 : 0.1156    mrr@10 : 0.3892    ndcg@10 : 0.1876    hit@10 : 0.7034    precision@10 : 0.1544    map@10 : 0.0952
# 27 Dec 05:33    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:33    INFO  epoch 18 training [time: 0.20s, train loss: 17365.3132]
# 27 Dec 05:34    INFO  epoch 18 evaluating [time: 48.22s, valid_score: 0.119300]
# 27 Dec 05:34    INFO  valid result:
# recall@10 : 0.1193    mrr@10 : 0.3924    ndcg@10 : 0.1909    hit@10 : 0.7123    precision@10 : 0.1573    map@10 : 0.0969
# 27 Dec 05:34    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:34    INFO  epoch 19 training [time: 0.21s, train loss: 17281.1812]
# 27 Dec 05:35    INFO  epoch 19 evaluating [time: 48.01s, valid_score: 0.119600]
# 27 Dec 05:35    INFO  valid result:
# recall@10 : 0.1196    mrr@10 : 0.3954    ndcg@10 : 0.1926    hit@10 : 0.7158    precision@10 : 0.1591    map@10 : 0.098
# 27 Dec 05:35    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:35    INFO  epoch 20 training [time: 0.20s, train loss: 17289.4038]
# 27 Dec 05:35    INFO  epoch 20 evaluating [time: 48.12s, valid_score: 0.121200]
# 27 Dec 05:35    INFO  valid result:
# recall@10 : 0.1212    mrr@10 : 0.4005    ndcg@10 : 0.1956    hit@10 : 0.7202    precision@10 : 0.1611    map@10 : 0.1003
# 27 Dec 05:35    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:35    INFO  epoch 21 training [time: 0.21s, train loss: 17239.6261]
# 27 Dec 05:36    INFO  epoch 21 evaluating [time: 48.98s, valid_score: 0.122700]
# 27 Dec 05:36    INFO  valid result:
# recall@10 : 0.1227    mrr@10 : 0.4065    ndcg@10 : 0.1986    hit@10 : 0.7248    precision@10 : 0.1632    map@10 : 0.1021
# 27 Dec 05:36    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:36    INFO  epoch 22 training [time: 0.21s, train loss: 17185.0273]
# 27 Dec 05:37    INFO  epoch 22 evaluating [time: 48.87s, valid_score: 0.124700]
# 27 Dec 05:37    INFO  valid result:
# recall@10 : 0.1247    mrr@10 : 0.414    ndcg@10 : 0.2027    hit@10 : 0.7302    precision@10 : 0.1664    map@10 : 0.1048
# 27 Dec 05:37    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:37    INFO  epoch 23 training [time: 0.21s, train loss: 17208.2802]
# 27 Dec 05:38    INFO  epoch 23 evaluating [time: 48.30s, valid_score: 0.125100]
# 27 Dec 05:38    INFO  valid result:
# recall@10 : 0.1251    mrr@10 : 0.4085    ndcg@10 : 0.2007    hit@10 : 0.7306    precision@10 : 0.1653    map@10 : 0.1032
# 27 Dec 05:38    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:38    INFO  epoch 24 training [time: 0.21s, train loss: 17154.2539]
# 27 Dec 05:39    INFO  epoch 24 evaluating [time: 48.02s, valid_score: 0.128700]
# 27 Dec 05:39    INFO  valid result:
# recall@10 : 0.1287    mrr@10 : 0.4239    ndcg@10 : 0.2084    hit@10 : 0.7393    precision@10 : 0.1705    map@10 : 0.1086
# 27 Dec 05:39    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:39    INFO  epoch 25 training [time: 0.21s, train loss: 17033.5482]
# 27 Dec 05:40    INFO  epoch 25 evaluating [time: 58.68s, valid_score: 0.132000]
# 27 Dec 05:40    INFO  valid result:
# recall@10 : 0.132    mrr@10 : 0.4314    ndcg@10 : 0.2142    hit@10 : 0.7496    precision@10 : 0.1758    map@10 : 0.1126
# 27 Dec 05:40    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:40    INFO  epoch 26 training [time: 0.21s, train loss: 17038.5703]
# 27 Dec 05:41    INFO  epoch 26 evaluating [time: 78.31s, valid_score: 0.132700]
# 27 Dec 05:41    INFO  valid result:
# recall@10 : 0.1327    mrr@10 : 0.4281    ndcg@10 : 0.2136    hit@10 : 0.7503    precision@10 : 0.176    map@10 : 0.1118
# 27 Dec 05:41    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:41    INFO  epoch 27 training [time: 0.21s, train loss: 17006.6511]
# 27 Dec 05:42    INFO  epoch 27 evaluating [time: 77.58s, valid_score: 0.134900]
# 27 Dec 05:42    INFO  valid result:
# recall@10 : 0.1349    mrr@10 : 0.4339    ndcg@10 : 0.2174    hit@10 : 0.7566    precision@10 : 0.179    map@10 : 0.1144
# 27 Dec 05:42    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:42    INFO  epoch 28 training [time: 0.21s, train loss: 17000.1116]
# 27 Dec 05:43    INFO  epoch 28 evaluating [time: 49.05s, valid_score: 0.136400]
# 27 Dec 05:43    INFO  valid result:
# recall@10 : 0.1364    mrr@10 : 0.4338    ndcg@10 : 0.218    hit@10 : 0.7616    precision@10 : 0.1798    map@10 : 0.1143
# 27 Dec 05:43    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:43    INFO  epoch 29 training [time: 0.20s, train loss: 16957.3796]
# 27 Dec 05:44    INFO  epoch 29 evaluating [time: 48.18s, valid_score: 0.138200]
# 27 Dec 05:44    INFO  valid result:
# recall@10 : 0.1382    mrr@10 : 0.4346    ndcg@10 : 0.22    hit@10 : 0.7649    precision@10 : 0.1823    map@10 : 0.1157
# 27 Dec 05:44    INFO  Saving current: saved/MultiVAE-Dec-27-2022_05-18-40.pth
# 27 Dec 05:44    INFO  best valid : OrderedDict([('recall@10', 0.1382), ('mrr@10', 0.4346), ('ndcg@10', 0.22), ('hit@10', 0.7649), ('precision@10', 0.1823), ('map@10', 0.1157)])
# 27 Dec 05:44    INFO  test result: None
# It took 26.96 mins
# {'best_valid_score': 0.1382, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.1382), ('mrr@10', 0.4346), ('ndcg@10', 0.22), ('hit@10', 0.7649), ('precision@10', 0.1823), ('map@10', 0.1157)]), 'test_result': None}
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>█▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>valid/hit@10</td><td>▁▁▁▁▁▂▂▂▃▃▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid/map@10</td><td>▁▁▂▁▁▁▂▂▃▃▄▄▄▄▅▅▅▅▅▆▆▆▇▆▇█▇███</td></tr><tr><td>valid/mrr@10</td><td>▁▁▂▂▂▂▂▃▃▄▄▄▅▄▅▆▆▆▆▆▆▇▇▇▇█████</td></tr><tr><td>valid/ndcg@10</td><td>▁▁▂▁▁▁▂▂▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▆▇█▇███</td></tr><tr><td>valid/precision@10</td><td>▁▁▁▁▁▁▂▂▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇███</td></tr><tr><td>valid/recall@10</td><td>▁▁▁▁▁▂▂▂▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇███</td></tr><tr><td>valid_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/hit@10</td><td>0.7649</td></tr><tr><td>eval/map@10</td><td>0.1157</td></tr><tr><td>eval/mrr@10</td><td>0.4346</td></tr><tr><td>eval/ndcg@10</td><td>0.22</td></tr><tr><td>eval/precision@10</td><td>0.1823</td></tr><tr><td>eval/recall@10</td><td>0.1382</td></tr><tr><td>train/epoch</td><td>29</td></tr><tr><td>train/train_loss</td><td>16957.37958</td></tr><tr><td>train_step</td><td>29</td></tr><tr><td>valid/hit@10</td><td>0.7649</td></tr><tr><td>valid/map@10</td><td>0.1157</td></tr><tr><td>valid/mrr@10</td><td>0.4346</td></tr><tr><td>valid/ndcg@10</td><td>0.22</td></tr><tr><td>valid/precision@10</td><td>0.1823</td></tr><tr><td>valid/recall@10</td><td>0.1382</td></tr><tr><td>valid_step</td><td>29</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">laced-dust-4</strong>: <a href="https://wandb.ai/recsys8/Recbole/runs/5td1kqi2" target="_blank">https://wandb.ai/recsys8/Recbole/runs/5td1kqi2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_051836-5td1kqi2/logs</code>
# running MultiDAE...
# 27 Dec 05:44    INFO  ['/opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9008', '--control=9006', '--hb=9005', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"7fd8b746-1a87-4b32-97c0-fccd01819acb"', '--shell=9007', '--transport="tcp"', '--iopub=9009', '--f=/opt/ml/.local/share/jupyter/runtime/kernel-v2-48980F7V0o03cn7e6.json']
# 27 Dec 05:44    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/train_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 30
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 1, 0]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = Recall@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = Recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600, 400, 200]
# latent_dimension = 64
# dropout_prob = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 27 Dec 05:45    INFO  train_data
# The number of users: 31361
# Average actions of users: 164.36450892857144
# The number of items: 6808
# Average actions of items: 757.2309387395328
# The number of inters: 5154471
# The sparsity of the dataset: 97.58579218741939%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 27 Dec 05:45    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 27 Dec 05:45    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 1, 0]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 27 Dec 05:45    WARNING  Max value of user's history interaction records has reached 38.49882491186839% of the total.
# 27 Dec 05:45    INFO  MultiDAE(
#   (encoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=6808, out_features=600, bias=True)
#       (2): Tanh()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): Linear(in_features=600, out_features=400, bias=True)
#       (5): Tanh()
#       (6): Dropout(p=0.0, inplace=False)
#       (7): Linear(in_features=400, out_features=200, bias=True)
#       (8): Tanh()
#       (9): Dropout(p=0.0, inplace=False)
#       (10): Linear(in_features=200, out_features=64, bias=True)
#       (11): Tanh()
#     )
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=200, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=200, out_features=400, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=400, out_features=600, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=600, out_features=6808, bias=True)
#   )
# )
# Trainable parameters: 8844472
# 27 Dec 05:45    INFO  FLOPs: 8835200.0
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/opt/ml/input/MR/Recbole/general/wandb/run-20221227_054530-3i2rlo45</code>
# Syncing run <strong><a href="https://wandb.ai/recsys8/Recbole/runs/3i2rlo45" target="_blank">jumping-violet-5</a></strong> to <a href="https://wandb.ai/recsys8/Recbole" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 27 Dec 05:45    INFO  epoch 0 training [time: 0.20s, train loss: 19194.7581]
# 27 Dec 05:46    INFO  epoch 0 evaluating [time: 49.39s, valid_score: 0.085800]
# 27 Dec 05:46    INFO  valid result:
# recall@10 : 0.0858    mrr@10 : 0.2954    ndcg@10 : 0.1372    hit@10 : 0.5922    precision@10 : 0.1148    map@10 : 0.0648
# 27 Dec 05:46    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:46    INFO  epoch 1 training [time: 0.20s, train loss: 18393.0508]
# 27 Dec 05:47    INFO  epoch 1 evaluating [time: 49.79s, valid_score: 0.086900]
# 27 Dec 05:47    INFO  valid result:
# recall@10 : 0.0869    mrr@10 : 0.2984    ndcg@10 : 0.139    hit@10 : 0.5961    precision@10 : 0.116    map@10 : 0.0661
# 27 Dec 05:47    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:47    INFO  epoch 2 training [time: 0.20s, train loss: 18373.1202]
# 27 Dec 05:48    INFO  epoch 2 evaluating [time: 49.83s, valid_score: 0.088000]
# 27 Dec 05:48    INFO  valid result:
# recall@10 : 0.088    mrr@10 : 0.3084    ndcg@10 : 0.1424    hit@10 : 0.5973    precision@10 : 0.1173    map@10 : 0.0686
# 27 Dec 05:48    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:48    INFO  epoch 3 training [time: 0.20s, train loss: 18328.5830]
# 27 Dec 05:48    INFO  epoch 3 evaluating [time: 49.14s, valid_score: 0.086900]
# 27 Dec 05:48    INFO  valid result:
# recall@10 : 0.0869    mrr@10 : 0.3097    ndcg@10 : 0.1413    hit@10 : 0.5944    precision@10 : 0.1161    map@10 : 0.0677
# 27 Dec 05:48    INFO  epoch 4 training [time: 0.20s, train loss: 18236.9137]
# 27 Dec 05:49    INFO  epoch 4 evaluating [time: 49.27s, valid_score: 0.088100]
# 27 Dec 05:49    INFO  valid result:
# recall@10 : 0.0881    mrr@10 : 0.3058    ndcg@10 : 0.1407    hit@10 : 0.6025    precision@10 : 0.1165    map@10 : 0.0669
# 27 Dec 05:49    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:49    INFO  epoch 5 training [time: 0.20s, train loss: 18103.4862]
# 27 Dec 05:50    INFO  epoch 5 evaluating [time: 48.51s, valid_score: 0.090500]
# 27 Dec 05:50    INFO  valid result:
# recall@10 : 0.0905    mrr@10 : 0.3154    ndcg@10 : 0.1457    hit@10 : 0.6122    precision@10 : 0.1203    map@10 : 0.07
# 27 Dec 05:50    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:50    INFO  epoch 6 training [time: 0.20s, train loss: 18103.9545]
# 27 Dec 05:51    INFO  epoch 6 evaluating [time: 49.37s, valid_score: 0.092500]
# 27 Dec 05:51    INFO  valid result:
# recall@10 : 0.0925    mrr@10 : 0.3227    ndcg@10 : 0.1489    hit@10 : 0.6163    precision@10 : 0.1221    map@10 : 0.0721
# 27 Dec 05:51    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:51    INFO  epoch 7 training [time: 0.20s, train loss: 18038.3420]
# 27 Dec 05:52    INFO  epoch 7 evaluating [time: 49.29s, valid_score: 0.095100]
# 27 Dec 05:52    INFO  valid result:
# recall@10 : 0.0951    mrr@10 : 0.3304    ndcg@10 : 0.1534    hit@10 : 0.6221    precision@10 : 0.1255    map@10 : 0.075
# 27 Dec 05:52    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:52    INFO  epoch 8 training [time: 0.21s, train loss: 18010.6261]
# 27 Dec 05:53    INFO  epoch 8 evaluating [time: 49.97s, valid_score: 0.097300]
# 27 Dec 05:53    INFO  valid result:
# recall@10 : 0.0973    mrr@10 : 0.3338    ndcg@10 : 0.1577    hit@10 : 0.6302    precision@10 : 0.1302    map@10 : 0.0777
# 27 Dec 05:53    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:53    INFO  epoch 9 training [time: 0.20s, train loss: 17809.1884]
# 27 Dec 05:53    INFO  epoch 9 evaluating [time: 49.61s, valid_score: 0.102800]
# 27 Dec 05:53    INFO  valid result:
# recall@10 : 0.1028    mrr@10 : 0.345    ndcg@10 : 0.1634    hit@10 : 0.6566    precision@10 : 0.1354    map@10 : 0.08
# 27 Dec 05:53    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:53    INFO  epoch 10 training [time: 0.20s, train loss: 17745.0519]
# 27 Dec 05:54    INFO  epoch 10 evaluating [time: 49.48s, valid_score: 0.104500]
# 27 Dec 05:54    INFO  valid result:
# recall@10 : 0.1045    mrr@10 : 0.3558    ndcg@10 : 0.169    hit@10 : 0.6644    precision@10 : 0.1395    map@10 : 0.084
# 27 Dec 05:54    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:54    INFO  epoch 11 training [time: 0.20s, train loss: 17722.9304]
# 27 Dec 05:55    INFO  epoch 11 evaluating [time: 50.07s, valid_score: 0.106100]
# 27 Dec 05:55    INFO  valid result:
# recall@10 : 0.1061    mrr@10 : 0.3582    ndcg@10 : 0.1705    hit@10 : 0.6676    precision@10 : 0.1407    map@10 : 0.0848
# 27 Dec 05:55    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:55    INFO  epoch 12 training [time: 0.19s, train loss: 17680.9998]
# 27 Dec 05:56    INFO  epoch 12 evaluating [time: 49.51s, valid_score: 0.104700]
# 27 Dec 05:56    INFO  valid result:
# recall@10 : 0.1047    mrr@10 : 0.3511    ndcg@10 : 0.1665    hit@10 : 0.6642    precision@10 : 0.1376    map@10 : 0.082
# 27 Dec 05:56    INFO  epoch 13 training [time: 0.20s, train loss: 17715.7939]
# 27 Dec 05:57    INFO  epoch 13 evaluating [time: 49.63s, valid_score: 0.107800]
# 27 Dec 05:57    INFO  valid result:
# recall@10 : 0.1078    mrr@10 : 0.3651    ndcg@10 : 0.1753    hit@10 : 0.6768    precision@10 : 0.145    map@10 : 0.0881
# 27 Dec 05:57    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:57    INFO  epoch 14 training [time: 0.20s, train loss: 17670.9554]
# 27 Dec 05:58    INFO  epoch 14 evaluating [time: 49.48s, valid_score: 0.108300]
# 27 Dec 05:58    INFO  valid result:
# recall@10 : 0.1083    mrr@10 : 0.3682    ndcg@10 : 0.1769    hit@10 : 0.6782    precision@10 : 0.1461    map@10 : 0.0892
# 27 Dec 05:58    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:58    INFO  epoch 15 training [time: 0.20s, train loss: 17577.3667]
# 27 Dec 05:58    INFO  epoch 15 evaluating [time: 49.43s, valid_score: 0.109000]
# 27 Dec 05:58    INFO  valid result:
# recall@10 : 0.109    mrr@10 : 0.3638    ndcg@10 : 0.1746    hit@10 : 0.6765    precision@10 : 0.1442    map@10 : 0.0873
# 27 Dec 05:58    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:58    INFO  epoch 16 training [time: 0.20s, train loss: 17510.4602]
# 27 Dec 05:59    INFO  epoch 16 evaluating [time: 49.58s, valid_score: 0.111300]
# 27 Dec 05:59    INFO  valid result:
# recall@10 : 0.1113    mrr@10 : 0.3728    ndcg@10 : 0.1787    hit@10 : 0.6875    precision@10 : 0.1474    map@10 : 0.0895
# 27 Dec 05:59    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 05:59    INFO  epoch 17 training [time: 0.20s, train loss: 17446.0668]
# 27 Dec 06:00    INFO  epoch 17 evaluating [time: 49.37s, valid_score: 0.113100]
# 27 Dec 06:00    INFO  valid result:
# recall@10 : 0.1131    mrr@10 : 0.3805    ndcg@10 : 0.1829    hit@10 : 0.6952    precision@10 : 0.1507    map@10 : 0.0922
# 27 Dec 06:00    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:00    INFO  epoch 18 training [time: 0.20s, train loss: 17464.1848]
# 27 Dec 06:01    INFO  epoch 18 evaluating [time: 49.23s, valid_score: 0.115000]
# 27 Dec 06:01    INFO  valid result:
# recall@10 : 0.115    mrr@10 : 0.3859    ndcg@10 : 0.1856    hit@10 : 0.7018    precision@10 : 0.1527    map@10 : 0.0937
# 27 Dec 06:01    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:01    INFO  epoch 19 training [time: 0.20s, train loss: 17403.8718]
# 27 Dec 06:02    INFO  epoch 19 evaluating [time: 49.52s, valid_score: 0.115500]
# 27 Dec 06:02    INFO  valid result:
# recall@10 : 0.1155    mrr@10 : 0.384    ndcg@10 : 0.1844    hit@10 : 0.7    precision@10 : 0.1516    map@10 : 0.0928
# 27 Dec 06:02    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:02    INFO  epoch 20 training [time: 0.21s, train loss: 17359.7957]
# 27 Dec 06:03    INFO  epoch 20 evaluating [time: 49.25s, valid_score: 0.118800]
# 27 Dec 06:03    INFO  valid result:
# recall@10 : 0.1188    mrr@10 : 0.3899    ndcg@10 : 0.1904    hit@10 : 0.71    precision@10 : 0.1574    map@10 : 0.0968
# 27 Dec 06:03    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:03    INFO  epoch 21 training [time: 0.20s, train loss: 17283.6766]
# 27 Dec 06:03    INFO  epoch 21 evaluating [time: 49.16s, valid_score: 0.120100]
# 27 Dec 06:03    INFO  valid result:
# recall@10 : 0.1201    mrr@10 : 0.3922    ndcg@10 : 0.1919    hit@10 : 0.7133    precision@10 : 0.1585    map@10 : 0.0977
# 27 Dec 06:03    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:03    INFO  epoch 22 training [time: 0.20s, train loss: 17224.5663]
# 27 Dec 06:04    INFO  epoch 22 evaluating [time: 49.81s, valid_score: 0.120800]
# 27 Dec 06:04    INFO  valid result:
# recall@10 : 0.1208    mrr@10 : 0.3999    ndcg@10 : 0.1953    hit@10 : 0.7185    precision@10 : 0.1608    map@10 : 0.1001
# 27 Dec 06:04    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:04    INFO  epoch 23 training [time: 0.20s, train loss: 17274.4913]
# 27 Dec 06:05    INFO  epoch 23 evaluating [time: 49.46s, valid_score: 0.121300]
# 27 Dec 06:05    INFO  valid result:
# recall@10 : 0.1213    mrr@10 : 0.4017    ndcg@10 : 0.1957    hit@10 : 0.7207    precision@10 : 0.1611    map@10 : 0.1001
# 27 Dec 06:05    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:05    INFO  epoch 24 training [time: 0.20s, train loss: 17248.9471]
# 27 Dec 06:06    INFO  epoch 24 evaluating [time: 49.28s, valid_score: 0.124400]
# 27 Dec 06:06    INFO  valid result:
# recall@10 : 0.1244    mrr@10 : 0.4141    ndcg@10 : 0.202    hit@10 : 0.7294    precision@10 : 0.1657    map@10 : 0.1042
# 27 Dec 06:06    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:06    INFO  epoch 25 training [time: 0.20s, train loss: 17113.6339]
# 27 Dec 06:07    INFO  epoch 25 evaluating [time: 49.80s, valid_score: 0.126600]
# 27 Dec 06:07    INFO  valid result:
# recall@10 : 0.1266    mrr@10 : 0.4114    ndcg@10 : 0.2019    hit@10 : 0.7339    precision@10 : 0.1662    map@10 : 0.1037
# 27 Dec 06:07    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:07    INFO  epoch 26 training [time: 0.20s, train loss: 17136.5753]
# 27 Dec 06:08    INFO  epoch 26 evaluating [time: 48.72s, valid_score: 0.130000]
# 27 Dec 06:08    INFO  valid result:
# recall@10 : 0.13    mrr@10 : 0.4234    ndcg@10 : 0.2091    hit@10 : 0.743    precision@10 : 0.1718    map@10 : 0.1086
# 27 Dec 06:08    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:08    INFO  epoch 27 training [time: 0.20s, train loss: 17077.0286]
# 27 Dec 06:08    INFO  epoch 27 evaluating [time: 49.73s, valid_score: 0.133500]
# 27 Dec 06:08    INFO  valid result:
# recall@10 : 0.1335    mrr@10 : 0.4363    ndcg@10 : 0.217    hit@10 : 0.7518    precision@10 : 0.1777    map@10 : 0.1144
# 27 Dec 06:08    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:08    INFO  epoch 28 training [time: 0.20s, train loss: 17059.1421]
# 27 Dec 06:09    INFO  epoch 28 evaluating [time: 49.50s, valid_score: 0.134400]
# 27 Dec 06:09    INFO  valid result:
# recall@10 : 0.1344    mrr@10 : 0.437    ndcg@10 : 0.218    hit@10 : 0.7541    precision@10 : 0.1787    map@10 : 0.1151
# 27 Dec 06:09    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:09    INFO  epoch 29 training [time: 0.20s, train loss: 17028.1399]
# 27 Dec 06:10    INFO  epoch 29 evaluating [time: 49.23s, valid_score: 0.135000]
# 27 Dec 06:10    INFO  valid result:
# recall@10 : 0.135    mrr@10 : 0.4366    ndcg@10 : 0.219    hit@10 : 0.7548    precision@10 : 0.1801    map@10 : 0.1158
# 27 Dec 06:10    INFO  Saving current: saved/MultiDAE-Dec-27-2022_05-45-34.pth
# 27 Dec 06:10    INFO  best valid : OrderedDict([('recall@10', 0.135), ('mrr@10', 0.4366), ('ndcg@10', 0.219), ('hit@10', 0.7548), ('precision@10', 0.1801), ('map@10', 0.1158)])
# 27 Dec 06:10    INFO  test result: None
# It took 25.99 mins
# {'best_valid_score': 0.135, 'valid_score_bigger': True, 'best_valid_result': OrderedDict([('recall@10', 0.135), ('mrr@10', 0.4366), ('ndcg@10', 0.219), ('hit@10', 0.7548), ('precision@10', 0.1801), ('map@10', 0.1158)]), 'test_result': None}
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>█▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>valid/hit@10</td><td>▁▁▁▁▁▂▂▂▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>valid/map@10</td><td>▁▁▂▁▁▂▂▂▃▃▄▄▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇███</td></tr><tr><td>valid/mrr@10</td><td>▁▁▂▂▂▂▂▃▃▃▄▄▄▄▅▄▅▅▅▅▆▆▆▆▇▇▇███</td></tr><tr><td>valid/ndcg@10</td><td>▁▁▁▁▁▂▂▂▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇███</td></tr><tr><td>valid/precision@10</td><td>▁▁▁▁▁▂▂▂▃▃▄▄▃▄▄▄▄▅▅▅▆▆▆▆▆▇▇███</td></tr><tr><td>valid/recall@10</td><td>▁▁▁▁▁▂▂▂▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇███</td></tr><tr><td>valid_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/hit@10</td><td>0.7548</td></tr><tr><td>eval/map@10</td><td>0.1158</td></tr><tr><td>eval/mrr@10</td><td>0.4366</td></tr><tr><td>eval/ndcg@10</td><td>0.219</td></tr><tr><td>eval/precision@10</td><td>0.1801</td></tr><tr><td>eval/recall@10</td><td>0.135</td></tr><tr><td>train/epoch</td><td>29</td></tr><tr><td>train/train_loss</td><td>17028.13989</td></tr><tr><td>train_step</td><td>29</td></tr><tr><td>valid/hit@10</td><td>0.7548</td></tr><tr><td>valid/map@10</td><td>0.1158</td></tr><tr><td>valid/mrr@10</td><td>0.4366</td></tr><tr><td>valid/ndcg@10</td><td>0.219</td></tr><tr><td>valid/precision@10</td><td>0.1801</td></tr><tr><td>valid/recall@10</td><td>0.135</td></tr><tr><td>valid_step</td><td>29</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jumping-violet-5</strong>: <a href="https://wandb.ai/recsys8/Recbole/runs/3i2rlo45" target="_blank">https://wandb.ai/recsys8/Recbole/runs/3i2rlo45</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_054530-3i2rlo45/logs</code>

# %% [markdown]
# ### Model Load

# %%
model_path='./saved/EASE-Dec-26-2022_18-01-48.pth'
# rank K 설정
K = 10

# %% [markdown]
# ### Inference

# %%
# config, model, dataset 불러오기
checkpoint = torch.load(model_path)
config = checkpoint['config']
config['dataset'] = 'train_data'

dataset = create_dataset(config)
train_data, valid_data, test_data = data_preparation(config, dataset)

model = get_model(config['model'])(config, test_data.dataset).to(config['device'])
model.load_state_dict(checkpoint['state_dict'])
model.load_other_parameter(checkpoint.get('other_parameter'))

# device 설정
device = config.final_config_dict['device']

# user, item id -> token 변환 array
user_id = config['USER_ID_FIELD']
item_id = config['ITEM_ID_FIELD']
user_id2token = dataset.field2id_token[user_id]
item_id2token = dataset.field2id_token[item_id]

# user id list
all_user_list = torch.arange(1, len(user_id2token)).view(-1,128) # 245, 128

# user, item 길이
user_len = len(user_id2token) # 31361 (PAD 포함)
item_len = len(item_id2token) # 6808 (PAD 포함)

# user-item sparse matrix
matrix = dataset.inter_matrix(form='csr') # (31361, 6808)

# user id, predict item id 저장 변수
pred_list = None
user_list = None

# model 평가모드 전환
model.eval()

# progress bar 설정
tbar = tqdm(all_user_list, desc=set_color(f"Inference", 'pink')) # 245, 128

for data in tbar: # data: 128, 
    # interaction 생성
    interaction = dict()
    interaction = Interaction(interaction)
    interaction[user_id] = data
    interaction = interaction.to(device)

    # user item별 score 예측
    score = model.full_sort_predict(interaction) # [1, 871424]
    score = score.view(-1, item_len) # 128, 6808

    rating_pred = score.cpu().data.numpy().copy() # 128, 6808

    user_index = data.numpy() # 128,

    # idx에는 128명의 영화상호작용이 True, False로 있다.
    idx = matrix[user_index].toarray() > 0 # idx shape: 128, 6808

    rating_pred[idx] = -np.inf # idx에서 True부분이 -inf로 변경
    rating_pred[:, 0] = -np.inf # 첫번째 PAD 열도 -inf로 변경
    
    # np.argpartition(배열, -K) : 배열에서 순서 상관없이 큰 값 K개를 뽑아 오른쪽에 놓겠다 -> 인덱스반환
    # rating_pred에서 각 행마다 K개의 score가 큰 인덱스를 오른쪽에 두고, 그 K개만 가져오기
    ind = np.argpartition(rating_pred, -K)[:, -K:] # rating_pred: (128, 6808) -> ind: (128, 20)

    user_row_index = np.arange(len(rating_pred)).reshape(-1,1) # [[0],[1],...,[127]]
    arr_ind = rating_pred[user_row_index, ind] # 128, 6808 -> 128, 20

    # arr_ind 내부에서 행별로, 내림차순 정렬해서 index 나오도록
    arr_ind_argsort = np.argsort(arr_ind)[np.arange(len(rating_pred)), ::-1]

    # ind는 item의 real index를 갖는 128,20 -> arr_ind_argsort를 통해 pred가 높은 상위 20개 read index 추출
    batch_pred_list = ind[user_row_index, arr_ind_argsort] # 128,20 -> 128,20

    if pred_list is None: # 처음에는 직접 정의
        pred_list = batch_pred_list
        user_list = user_index
    else: # pred_list가 있을 때는, append
        pred_list = np.append(pred_list, batch_pred_list, axis=0)
        user_list = np.append(
            user_list, user_index, axis=0
        )

result = []
for user, pred in zip(user_list, pred_list):
    for item in pred:
        result.append((int(user_id2token[user]), int(item_id2token[item])))

# 데이터 저장
sub = pd.DataFrame(result, columns=["user", "item"])
sub.to_csv(
    "submission.csv", index=False
)
print('inference done!')

# %% [markdown]
# ### Submission

# %%
sub = pd.read_csv('submission.csv')
sub.user = sub.user.map(uidx2user)
sub.item = sub.item.map(iidx2item)
sub.to_csv('model_version.csv',index=False)
